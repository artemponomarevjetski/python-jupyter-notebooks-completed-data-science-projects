# %% [markdown]
# Johson & Johson assignment

# %% [markdown]
# Task A*

# %% [markdown]
# 1	Create Chart #1 below the data set that shows the number of Defects over time.

# %%
import pandas as pd

df = pd.read_csv("Task A-Table 1.csv")
df.head()
# Out:
#      Product  Month ID (YYYYMM)  Defects  Opportunities   Defect Rates  \
# 0  Product A             201607       37     222.000000  166666.666667
# 1  Product A             201608       26      36.000000  722222.222222
# 2  Product A             201609       66     375.000000  176000.000000
# 3  Product A             201610       61     494.000000  123481.781377
# 4  Product A             201611       64     980.333333   65283.917035
#
#      Mean Rate  2 Sigma Limit  3 Sigma Limit
# 0  81319.08913  188681.909296  242363.319379
# 1  81319.08913  188681.909296  242363.319379
# 2  81319.08913  188681.909296  242363.319379
# 3  81319.08913  188681.909296  242363.319379
# 4  81319.08913  188681.909296  242363.319379

# %%
# Import necessary packages
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
#import earthpy as et

#read data from csv
df = pd.read_csv('Task A-Table 1.csv', usecols=['Month ID (YYYYMM)','Defects'])
df['Month ID (YYYYMM)'] = pd.to_datetime(df['Month ID (YYYYMM)'], format='%Y%m').dt.strftime("%Y-%m")

#set date as index
df.set_index('Month ID (YYYYMM)')

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.bar(df['Month ID (YYYYMM)'],
        df['Defects'],
        color='purple')

# Set title and labels for axes
ax.set(xlabel="Time",
       ylabel="Number of defects",
       title="The number of Defects over time")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %% [markdown]
# 2	Create Chart #2 below the data set that shows the number of Opportunities over time.

# %%
# Import necessary packages
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns


#read data from csv
df = pd.read_csv('Task A-Table 1.csv', usecols=['Month ID (YYYYMM)','Opportunities'])
df['Month ID (YYYYMM)'] = pd.to_datetime(df['Month ID (YYYYMM)'], format='%Y%m').dt.strftime("%Y-%m")

#set date as index
df.set_index('Month ID (YYYYMM)')

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.bar(df['Month ID (YYYYMM)'],
        df['Opportunities'],
        color='purple')

# Set title and labels for axes
ax.set(xlabel="Time",
       ylabel="Number of Opportunities",
       title="The number of Opportunities over time")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %% [markdown]
# 3	Create Chart #3 below the data set that shows the Defect Rates with the Mean Rate and Limits over time.

# %%
# Import necessary packages
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns


# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

#read data from csv
df = pd.read_csv('Task A-Table 1.csv', usecols=['Month ID (YYYYMM)','Defect Rates', 'Mean Rate', '2 Sigma Limit', '3 Sigma Limit'])
df['Month ID (YYYYMM)'] = pd.to_datetime(df['Month ID (YYYYMM)'], format='%Y%m').dt.strftime("%Y-%m")

#set date as index
df.set_index('Month ID (YYYYMM)')

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.plot(df['Month ID (YYYYMM)'],
        df['Defect Rates'],
        label='Defect Rates')

ax.plot(df['Month ID (YYYYMM)'],
        df['Mean Rate'],
        label='Mean Rate')

ax.plot(df['Month ID (YYYYMM)'],
        df['2 Sigma Limit'],
        label='2 Sigma Limit')

ax.plot(df['Month ID (YYYYMM)'],
        df['3 Sigma Limit'],
        label='3 Sigma Limit')

# show a legend on the plot
plt.legend()

# Set title and labels for axes
ax.set(xlabel="Time",
       ylabel="Rates",
       title="Defect Rates, Mean Rate, 2 Sigma Limit, 3 Sigma Limit")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)
plt.setp(ax.get_yticklabels(), rotation=-45)

plt.show()

# %% [markdown]
# 4	Create Chart #4 below the data set that shows all the information from Chart #1, Chart #2, and Chart #3. Chart #4 must be presentable to key stakeholders with different levels of mastery on the data (ranging from individual contributors to serior management and executives). Be mindful of formatting, clarify, and aesthetics.

# %%
5	Analyze Chart #4 and annotate at least three observations / findings specific to the data provided.
# Out:
#   File "<ipython-input-5-a1b4acc6a786>", line 1
#     5	Analyze Chart #4 and annotate at least three observations / findings specific to the data provided.
#      	^
# SyntaxError: invalid syntax

# %%
Task A can be completed using Excel, R, or Python. If using Excel, please provide workbook with answers; otherwise, please provide script.

# %%
				
	Task A*			
	1	Create Chart #1 below the data set that shows the number of Defects over time.		
	2	Create Chart #2 below the data set that shows the number of Opportunities over time.		
	3	Create Chart #3 below the data set that shows the Defect Rates with the Mean Rate and Limits over time.		
	4	Create Chart #4 below the data set that shows all the information from Chart #1, Chart #2, and Chart #3. Chart #4 must be presentable to key stakeholders with different levels of mastery on the data (ranging from individual contributors to serior management and executives). Be mindful of formatting, clarify, and aesthetics.		
	5	Analyze Chart #4 and annotate at least three observations / findings specific to the data provided.		
	*	Task A can be completed using Excel, R, or Python. If using Excel, please provide workbook with answers; otherwise, please provide script.		
				
	Task B**			
	1	Add Country to "Task B" sheet using mapping table provided in "Task B Country List" sheet.		
	2	Summarize "Task B" sheet reported volumes for each product; calculate percent difference between product volumes in 2020 and 2021.		
	3	Identify the top 3 countries with highest complaint volume in year 2020.		
	4	Defects are tagged as either HW, SW, or CS errors. Summarize complaint volumes for each of these categories.		
	**	Task B must be completed using R or Python; please provide script.
